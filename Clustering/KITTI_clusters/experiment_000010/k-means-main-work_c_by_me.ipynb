# %% [markdown]
# # PART 1

# %%
import open3d as o3d
import numpy as np

velodyne_file = 'D:/Cluster_proj/VIPCClustering/data/KITTI/velodyne/000010.bin'

velo_points = np.fromfile(velodyne_file, dtype=np.float32).reshape(-1, 4)
points_np = velo_points[:, :3]

pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points_np)

o3d.visualization.draw_geometries([pcd])

# %%
import open3d as o3d
import numpy as np

velodyne_file = 'D:/Cluster_proj/VIPCClustering/data/KITTI/velodyne/000010.bin'

velo_points = np.fromfile(velodyne_file, dtype=np.float32).reshape(-1, 4)
points_np = velo_points[:, :3]

pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points_np)

calib_file = 'D:/Cluster_proj/annotator/kitti/data_object/training/calib/000010.txt'

calib_data = {}

with open(calib_file, 'r') as f:
    for line in f:
        if ':' in line:
            key, value = line.strip().split(':')
            value = np.array([float(x) for x in value.strip().split()])
            calib_data[key.strip()] = value

bbox_list = []
for key, value in calib_data.items():
    if key.startswith('P') or key.startswith('R') or key.startswith('Tr'):
        continue
    if len(value) == 12:
        min_bound = value[:3]
        max_bound = value[3:6]
        bbox = o3d.geometry.AxisAlignedBoundingBox(min_bound=min_bound, max_bound=max_bound)
        bbox.color = (0, 0, 0)
        bbox_list.append(bbox)

o3d.visualization.draw_geometries([pcd, *bbox_list])

# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors


velodyne_file = 'D:/Cluster_proj/VIPCClustering/data/KITTI/velodyne/000010.bin'

velo_points = np.fromfile(velodyne_file, dtype=np.float32).reshape(-1, 4)
points_np = velo_points[:, :3]

if len(points_np) == 0:
    print("The point cloud is empty or the file contains no data.")
else:
    scaler = StandardScaler()
    scaled_points_np = scaler.fit_transform(points_np)

    cutting_height = -1.2
    cut_indices = np.where(points_np[:, 2] > cutting_height)[0]
    cut_points_np = points_np[cut_indices]
    cut_scaled_points_np = scaled_points_np[cut_indices]

    n_neighbors = 1

    nbrs = NearestNeighbors(n_neighbors=n_neighbors, algorithm='auto').fit(cut_scaled_points_np)
    distances, indices = nbrs.kneighbors(cut_scaled_points_np)

    avg_distances = np.mean(distances, axis=1)

    threshold_low = np.percentile(avg_distances, 1)

    filtered_indices = np.where(avg_distances <= threshold_low)[0]
    filtered_cut_points_np = cut_points_np[filtered_indices]

    num_clusters = 400
    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(filtered_cut_points_np)
    labels = kmeans.labels_

    max_label = labels.max()
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))

    kmeans_pcd = o3d.geometry.PointCloud()
    kmeans_pcd.points = o3d.utility.Vector3dVector(filtered_cut_points_np)
    kmeans_pcd.colors = o3d.utility.Vector3dVector(colors[:, :3])

    bbox_list = []
    for label in np.unique(labels):
        if label == -1:
            continue
        cluster_points = filtered_cut_points_np[labels == label]
        bbox = o3d.geometry.AxisAlignedBoundingBox.create_from_points(o3d.utility.Vector3dVector(cluster_points))
        bbox.color = (0, 0, 0)
        bbox_list.append(bbox)

    o3d.visualization.draw_geometries([kmeans_pcd] + bbox_list)

    print("Clusters with up to 200 points in each cluster:")
    unique_labels, counts = np.unique(labels, return_counts=True)
    sorted_clusters = sorted(zip(unique_labels, counts), key=lambda x: x[1], reverse=True)
    for cluster_label, point_count in sorted_clusters:
        if point_count <= 200:
            print(f"Cluster {cluster_label}: {point_count} points")
    
filtered_indices = np.ones(len(labels), dtype=bool)
for cluster_label, point_count in sorted_clusters:
    if point_count <= 200:
        filtered_indices[labels == cluster_label] = False

filtered_points_np = filtered_cut_points_np[filtered_indices]

filtered_pcd = o3d.geometry.PointCloud()
filtered_pcd.points = o3d.utility.Vector3dVector(filtered_points_np)

o3d.visualization.draw_geometries([filtered_pcd])
# Out:
# d:\Program\Anaconda\envs\tfenv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Clusters with up to 200 points in each cluster:
# Cluster 150: 200 points
# Cluster 230: 195 points
# Cluster 175: 194 points
# Cluster 350: 191 points
# Cluster 35: 187 points
# Cluster 73: 187 points
# Cluster 68: 185 points
# Cluster 51: 184 points
# Cluster 300: 184 points
# Cluster 244: 182 points
# Cluster 107: 180 points
# Cluster 115: 178 points
# Cluster 185: 177 points
# Cluster 95: 174 points
# Cluster 296: 173 points
# Cluster 104: 171 points
# Cluster 165: 171 points
# Cluster 242: 170 points
# Cluster 96: 168 points
# Cluster 103: 167 points
# Cluster 59: 162 points
# Cluster 153: 157 points
# Cluster 58: 156 points
# Cluster 380: 155 points
# Cluster 295: 154 points
# Cluster 32: 152 points
# Cluster 42: 149 points
# Cluster 194: 149 points
# Cluster 55: 148 points
# Cluster 386: 148 points
# Cluster 274: 146 points
# Cluster 3: 144 points
# Cluster 247: 144 points
# Cluster 337: 143 points
# Cluster 155: 142 points
# Cluster 101: 140 points
# Cluster 352: 135 points
# Cluster 11: 134 points
# Cluster 251: 132 points
# Cluster 287: 131 points
# Cluster 361: 131 points
# Cluster 339: 130 points
# Cluster 33: 127 points
# Cluster 46: 126 points
# Cluster 106: 126 points
# Cluster 276: 125 points
# Cluster 384: 124 points
# Cluster 196: 123 points
# Cluster 156: 120 points
# Cluster 233: 120 points
# Cluster 41: 118 points
# Cluster 213: 118 points
# Cluster 169: 117 points
# Cluster 285: 115 points
# Cluster 5: 114 points
# Cluster 48: 114 points
# Cluster 397: 114 points
# Cluster 310: 113 points
# Cluster 62: 112 points
# Cluster 280: 112 points
# Cluster 325: 112 points
# Cluster 4: 111 points
# Cluster 373: 111 points
# Cluster 382: 111 points
# Cluster 7: 110 points
# Cluster 188: 110 points
# Cluster 392: 110 points
# Cluster 396: 110 points
# Cluster 74: 108 points
# Cluster 82: 108 points
# Cluster 113: 108 points
# Cluster 10: 107 points
# Cluster 305: 107 points
# Cluster 334: 107 points
# Cluster 151: 106 points
# Cluster 78: 104 points
# Cluster 176: 103 points
# Cluster 371: 102 points
# Cluster 64: 101 points
# Cluster 174: 101 points
# Cluster 278: 101 points
# Cluster 312: 101 points
# Cluster 31: 100 points
# Cluster 336: 100 points
# Cluster 385: 100 points
# Cluster 166: 99 points
# Cluster 180: 99 points
# Cluster 225: 96 points
# Cluster 297: 95 points
# Cluster 298: 95 points
# Cluster 94: 93 points
# Cluster 306: 93 points
# Cluster 8: 91 points
# Cluster 97: 91 points
# Cluster 314: 89 points
# Cluster 212: 88 points
# Cluster 26: 87 points
# Cluster 214: 87 points
# Cluster 254: 87 points
# Cluster 323: 86 points
# Cluster 375: 86 points
# Cluster 18: 85 points
# Cluster 109: 83 points
# Cluster 224: 83 points
# Cluster 277: 83 points
# Cluster 20: 82 points
# Cluster 228: 82 points
# Cluster 302: 82 points
# Cluster 54: 81 points
# Cluster 147: 81 points
# Cluster 259: 81 points
# Cluster 272: 81 points
# Cluster 347: 81 points
# Cluster 301: 80 points
# Cluster 50: 79 points
# Cluster 57: 79 points
# Cluster 125: 79 points
# Cluster 149: 79 points
# Cluster 353: 79 points
# Cluster 290: 78 points
# Cluster 98: 76 points
# Cluster 219: 76 points
# Cluster 236: 76 points
# Cluster 245: 76 points
# Cluster 313: 76 points
# Cluster 360: 76 points
# Cluster 1: 75 points
# Cluster 243: 75 points
# Cluster 110: 74 points
# Cluster 112: 74 points
# Cluster 93: 73 points
# Cluster 246: 72 points
# Cluster 72: 71 points
# Cluster 183: 71 points
# Cluster 206: 71 points
# Cluster 315: 71 points
# Cluster 12: 70 points
# Cluster 256: 70 points
# Cluster 318: 70 points
# Cluster 322: 70 points
# Cluster 21: 69 points
# Cluster 145: 69 points
# Cluster 119: 67 points
# Cluster 304: 67 points
# Cluster 25: 66 points
# Cluster 231: 66 points
# Cluster 292: 66 points
# Cluster 163: 65 points
# Cluster 271: 65 points
# Cluster 317: 65 points
# Cluster 89: 64 points
# Cluster 237: 64 points
# Cluster 393: 64 points
# Cluster 309: 61 points
# Cluster 349: 61 points
# Cluster 37: 60 points
# Cluster 164: 60 points
# Cluster 173: 59 points
# Cluster 204: 59 points
# Cluster 238: 59 points
# Cluster 15: 57 points
# Cluster 197: 57 points
# Cluster 294: 57 points
# Cluster 161: 56 points
# Cluster 366: 56 points
# Cluster 387: 56 points
# Cluster 186: 55 points
# Cluster 221: 55 points
# Cluster 172: 54 points
# Cluster 195: 54 points
# Cluster 217: 54 points
# Cluster 291: 54 points
# Cluster 338: 54 points
# Cluster 14: 53 points
# Cluster 198: 53 points
# Cluster 332: 53 points
# Cluster 108: 52 points
# Cluster 157: 52 points
# Cluster 269: 52 points
# Cluster 43: 51 points
# Cluster 177: 51 points
# Cluster 209: 51 points
# Cluster 102: 50 points
# Cluster 122: 50 points
# Cluster 132: 50 points
# Cluster 223: 50 points
# Cluster 253: 50 points
# Cluster 330: 49 points
# Cluster 358: 49 points
# Cluster 136: 48 points
# Cluster 144: 48 points
# Cluster 187: 48 points
# Cluster 226: 48 points
# Cluster 374: 48 points
# Cluster 38: 47 points
# Cluster 190: 47 points
# Cluster 202: 47 points
# Cluster 262: 47 points
# Cluster 378: 47 points
# Cluster 66: 46 points
# Cluster 117: 46 points
# Cluster 370: 46 points
# Cluster 63: 45 points
# Cluster 148: 45 points
# Cluster 168: 45 points
# Cluster 220: 45 points
# Cluster 335: 45 points
# Cluster 91: 44 points
# Cluster 158: 44 points
# Cluster 167: 44 points
# Cluster 100: 43 points
# Cluster 2: 42 points
# Cluster 69: 42 points
# Cluster 121: 42 points
# Cluster 240: 42 points
# Cluster 346: 42 points
# Cluster 275: 41 points
# Cluster 311: 41 points
# Cluster 30: 40 points
# Cluster 137: 40 points
# Cluster 391: 40 points
# Cluster 181: 39 points
# Cluster 239: 39 points
# Cluster 270: 39 points
# Cluster 340: 39 points
# Cluster 39: 38 points
# Cluster 398: 38 points
# Cluster 65: 37 points
# Cluster 210: 37 points
# Cluster 261: 37 points
# Cluster 273: 37 points
# Cluster 320: 37 points
# Cluster 326: 37 points
# Cluster 36: 36 points
# Cluster 126: 36 points
# Cluster 135: 36 points
# Cluster 143: 36 points
# Cluster 171: 36 points
# Cluster 249: 36 points
# Cluster 61: 35 points
# Cluster 154: 35 points
# Cluster 199: 35 points
# Cluster 218: 35 points
# Cluster 284: 35 points
# Cluster 289: 35 points
# Cluster 377: 35 points
# Cluster 19: 34 points
# Cluster 260: 34 points
# Cluster 83: 33 points
# Cluster 229: 33 points
# Cluster 24: 32 points
# Cluster 47: 32 points
# Cluster 191: 32 points
# Cluster 45: 31 points
# Cluster 264: 31 points
# Cluster 359: 31 points
# Cluster 105: 30 points
# Cluster 128: 30 points
# Cluster 71: 29 points
# Cluster 123: 28 points
# Cluster 283: 28 points
# Cluster 44: 27 points
# Cluster 331: 27 points
# Cluster 90: 26 points
# Cluster 152: 26 points
# Cluster 227: 26 points
# Cluster 303: 26 points
# Cluster 308: 26 points
# Cluster 348: 26 points
# Cluster 116: 25 points
# Cluster 189: 25 points
# Cluster 367: 25 points
# Cluster 399: 25 points
# Cluster 53: 24 points
# Cluster 182: 24 points
# Cluster 288: 24 points
# Cluster 79: 23 points
# Cluster 131: 23 points
# Cluster 200: 23 points
# Cluster 395: 23 points
# Cluster 13: 22 points
# Cluster 381: 22 points
# Cluster 255: 21 points
# Cluster 316: 21 points
# Cluster 211: 20 points
# Cluster 56: 19 points
# Cluster 92: 19 points
# Cluster 203: 19 points
# Cluster 232: 19 points
# Cluster 345: 19 points
# Cluster 355: 19 points
# Cluster 379: 19 points
# Cluster 17: 18 points
# Cluster 81: 18 points
# Cluster 99: 18 points
# Cluster 118: 18 points
# Cluster 140: 18 points
# Cluster 282: 18 points
# Cluster 34: 17 points
# Cluster 52: 17 points
# Cluster 76: 17 points
# Cluster 87: 17 points
# Cluster 321: 17 points
# Cluster 365: 17 points
# Cluster 40: 16 points
# Cluster 193: 16 points
# Cluster 267: 16 points
# Cluster 363: 16 points
# Cluster 368: 16 points
# Cluster 60: 15 points
# Cluster 111: 15 points
# Cluster 114: 15 points
# Cluster 141: 15 points
# Cluster 216: 15 points
# Cluster 266: 15 points
# Cluster 293: 15 points
# Cluster 388: 15 points
# Cluster 0: 14 points
# Cluster 85: 14 points
# Cluster 88: 14 points
# Cluster 129: 14 points
# Cluster 258: 14 points
# Cluster 324: 14 points
# Cluster 369: 14 points
# Cluster 49: 13 points
# Cluster 142: 13 points
# Cluster 222: 13 points
# Cluster 364: 13 points
# Cluster 205: 12 points
# Cluster 351: 12 points
# Cluster 27: 11 points
# Cluster 146: 11 points
# Cluster 160: 11 points
# Cluster 184: 11 points
# Cluster 265: 11 points
# Cluster 279: 11 points
# Cluster 124: 10 points
# Cluster 162: 10 points
# Cluster 170: 10 points
# Cluster 208: 10 points
# Cluster 234: 10 points
# Cluster 286: 10 points
# Cluster 328: 10 points
# Cluster 329: 10 points
# Cluster 342: 10 points
# Cluster 362: 10 points
# Cluster 75: 8 points
# Cluster 341: 8 points
# Cluster 356: 8 points
# Cluster 390: 8 points
# Cluster 120: 7 points
# Cluster 84: 6 points
# Cluster 86: 6 points
# Cluster 248: 6 points
# Cluster 192: 5 points
# Cluster 207: 5 points
# Cluster 307: 5 points
# Cluster 343: 5 points
# Cluster 252: 4 points
# Cluster 344: 3 points
# Cluster 376: 3 points
# Cluster 394: 1 points

# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

points_np = filtered_points_np

if len(points_np) == 0:
    print("Облако точек пустое.")
else:
    scaler = StandardScaler()
    scaled_points_np = scaler.fit_transform(points_np)

    cutting_height = -1.2
    cut_indices = np.where(points_np[:, 2] > cutting_height)[0]
    cut_points_np = points_np[cut_indices]
    cut_scaled_points_np = scaled_points_np[cut_indices]

    n_neighbors = 1

    nbrs = NearestNeighbors(n_neighbors=n_neighbors, algorithm='auto').fit(cut_scaled_points_np)
    distances, indices = nbrs.kneighbors(cut_scaled_points_np)

    avg_distances = np.mean(distances, axis=1)

    threshold_low = np.percentile(avg_distances, 1)

    filtered_indices = np.where(avg_distances <= threshold_low)[0]
    filtered_points_np = cut_points_np[filtered_indices]

    center = np.mean(filtered_points_np, axis=0)

    center_point = o3d.geometry.TriangleMesh.create_sphere(radius=0.1)
    center_point.paint_uniform_color([1.0, 0.0, 0.0])
    center_point.translate(center)

    num_clusters = 15
    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(filtered_points_np)
    labels = kmeans.labels_

    max_label = labels.max()
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))

    kmeans_pcd = o3d.geometry.PointCloud()
    kmeans_pcd.points = o3d.utility.Vector3dVector(filtered_points_np)
    kmeans_pcd.colors = o3d.utility.Vector3dVector(colors[:, :3])

    bbox_list = []
    for label in np.unique(labels):
        if label == -1:
            continue
        cluster_points = filtered_points_np[labels == label]
        bbox = o3d.geometry.AxisAlignedBoundingBox.create_from_points(o3d.utility.Vector3dVector(cluster_points))
        bbox.color = (0, 0, 0)
        bbox_list.append(bbox)

    lines = []
    for cluster_center in kmeans.cluster_centers_:
        line = o3d.geometry.LineSet()
        line.points = o3d.utility.Vector3dVector([center, cluster_center])
        line.lines = o3d.utility.Vector2iVector([[0, 1]])
        line.colors = o3d.utility.Vector3dVector([[0, 0, 0]])
        lines.append(line)

    o3d.visualization.draw_geometries([kmeans_pcd, center_point] + bbox_list + lines)
# Out:
# d:\Program\Anaconda\envs\tfenv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# # 1

# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

points_np = filtered_points_np

if len(points_np) == 0:
    print("Облако точек пустое.")
else:
    scaler = StandardScaler()
    scaled_points_np = scaler.fit_transform(points_np)

    cutting_height = -1.2
    cut_indices = np.where(points_np[:, 2] > cutting_height)[0]
    cut_points_np = points_np[cut_indices]
    cut_scaled_points_np = scaled_points_np[cut_indices]

    n_neighbors = 1

    nbrs = NearestNeighbors(n_neighbors=n_neighbors, algorithm='auto').fit(cut_scaled_points_np)
    distances, indices = nbrs.kneighbors(cut_scaled_points_np)

    avg_distances = np.mean(distances, axis=1)

    threshold_low = np.percentile(avg_distances, 1)

    filtered_indices = np.where(avg_distances <= threshold_low)[0]
    filtered_points_np = cut_points_np[filtered_indices]

    center = np.mean(filtered_points_np, axis=0)

    center_point = o3d.geometry.TriangleMesh.create_sphere(radius=0.1)
    center_point.paint_uniform_color([1.0, 0.0, 0.0])
    center_point.translate(center)

    num_clusters = 15
    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(filtered_points_np)
    labels = kmeans.labels_

    lines = []
    points = []
    for cluster_center in kmeans.cluster_centers_:
        line = o3d.geometry.LineSet()
        line.points = o3d.utility.Vector3dVector([center, cluster_center])
        line.lines = o3d.utility.Vector2iVector([[0, 1]])
        line.colors = o3d.utility.Vector3dVector([[0, 0, 0]])
        lines.append(line)
        
        point = o3d.geometry.PointCloud()
        point.points = o3d.utility.Vector3dVector([cluster_center])
        point.paint_uniform_color([1.0, 0.0, 0.0])
        points.append(point)



    o3d.visualization.draw_geometries([center_point] + lines + points)
# Out:
# d:\Program\Anaconda\envs\tfenv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# # PART 2

# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

points_np = filtered_points_np  # filtered_points_np

if len(points_np) == 0:
    print("The point cloud is empty.")
else:
    scaler = StandardScaler()
    scaled_points_np = scaler.fit_transform(points_np)

    cutting_height = -1.2
    cut_indices = np.where(points_np[:, 2] > cutting_height)[0]
    cut_points_np = points_np[cut_indices]
    cut_scaled_points_np = scaled_points_np[cut_indices]

    n_neighbors = 1

    nbrs = NearestNeighbors(n_neighbors=n_neighbors, algorithm='auto').fit(cut_scaled_points_np)
    distances, indices = nbrs.kneighbors(cut_scaled_points_np)

    avg_distances = np.mean(distances, axis=1)

    threshold_low = np.percentile(avg_distances, 1)

    filtered_indices = np.where(avg_distances <= threshold_low)[0]
    filtered_points_np = cut_points_np[filtered_indices]

    center = np.mean(filtered_points_np, axis=0)

    center_point = o3d.geometry.TriangleMesh.create_sphere(radius=0.1)
    center_point.paint_uniform_color([1.0, 0.0, 0.0])
    center_point.translate(center)

    num_clusters = 15
    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(filtered_points_np)
    labels = kmeans.labels_

    max_label = labels.max()
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))

    kmeans_pcd = o3d.geometry.PointCloud()
    kmeans_pcd.points = o3d.utility.Vector3dVector(filtered_points_np)
    kmeans_pcd.colors = o3d.utility.Vector3dVector(colors[:, :3])

    bbox_list = []
    cluster_sizes = []
    for label in np.unique(labels):
        if label == -1:
            continue
        cluster_points = filtered_points_np[labels == label]
        bbox = o3d.geometry.AxisAlignedBoundingBox.create_from_points(o3d.utility.Vector3dVector(cluster_points))
        bbox.color = (0, 0, 0)
        bbox_list.append(bbox)
        cluster_sizes.append(len(cluster_points))

    lines = []
    for cluster_center in kmeans.cluster_centers_:
        line = o3d.geometry.LineSet()
        line.points = o3d.utility.Vector3dVector([center, cluster_center])
        line.lines = o3d.utility.Vector2iVector([[0, 1]])
        line.colors = o3d.utility.Vector3dVector([[0, 0, 0]])
        lines.append(line)

    o3d.visualization.draw_geometries([kmeans_pcd, center_point] + bbox_list + lines)

    for i, bbox in enumerate(bbox_list, 1):
        print(f"Bounding box {i}:")
        print(f"Center: {bbox.get_center()}")
        print(f"Dimensions: {bbox.get_extent()}")
        print(f"Number of points in a cluster: {cluster_sizes[i-1]}")
# Out:
# d:\Program\Anaconda\envs\tfenv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Bounding box 1:
# Center: [-4.53550005 -3.61149991 -0.7175    ]
# Dimensions: [3.40299988 2.00699973 0.963     ]
# Number of points in a cluster: 2165
# Bounding box 2:
# Center: [  2.54600006 -15.85900021  -0.2015    ]
# Dimensions: [4.05000007 4.00399971 1.995     ]
# Number of points in a cluster: 1406
# Bounding box 3:
# Center: [ 1.64599996  3.62149988 -0.6435    ]
# Dimensions: [3.02599992 6.32899979 1.111     ]
# Number of points in a cluster: 2941
# Bounding box 4:
# Center: [-9.42749977  7.47700024 -0.86500001]
# Dimensions: [1.61499977 1.3920002  0.66400003]
# Number of points in a cluster: 218
# Bounding box 5:
# Center: [16.5619998  -5.63849998 -0.71449998]
# Dimensions: [2.80000019 1.44700003 0.96699995]
# Number of points in a cluster: 251
# Bounding box 6:
# Center: [ -4.35450006 -12.64999962  -0.2385    ]
# Dimensions: [3.4749999  4.01399994 1.921     ]
# Number of points in a cluster: 2178
# Bounding box 7:
# Center: [ -1.05599999 -13.69000006  -0.24449998]
# Dimensions: [3.19799995 2.29799938 1.90699995]
# Number of points in a cluster: 1764
# Bounding box 8:
# Center: [ 4.51300013 -4.17350006 -0.76800001]
# Dimensions: [1.56000018 1.5710001  0.86199999]
# Number of points in a cluster: 1042
# Bounding box 9:
# Center: [-23.65350056  10.19449997   0.30850001]
# Dimensions: [0.35899925 1.65699959 1.55700001]
# Number of points in a cluster: 214
# Bounding box 10:
# Center: [12.05050039  3.55749995 -0.70350002]
# Dimensions: [3.73099995 4.45299995 0.98300005]
# Number of points in a cluster: 548
# Bounding box 11:
# Center: [-16.38850021   3.57199991  -0.55600002]
# Dimensions: [1.88100052 2.62199998 1.26200004]
# Number of points in a cluster: 293
# Bounding box 12:
# Center: [-11.47699976   3.33450013  -0.73800001]
# Dimensions: [2.42800045 3.1930002  0.92199999]
# Number of points in a cluster: 670
# Bounding box 13:
# Center: [ 6.71950006  7.27200007 -0.31249997]
# Dimensions: [1.11299992 0.5999999  1.73499995]
# Number of points in a cluster: 310
# Bounding box 14:
# Center: [-12.64650011  -5.03600001  -0.93850002]
# Dimensions: [1.66499996 1.38200045 0.51700002]
# Number of points in a cluster: 245
# Bounding box 15:
# Center: [  2.56349993 -11.28599977  -0.50499998]
# Dimensions: [1.77699995 1.03600025 1.38599995]
# Number of points in a cluster: 323

# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
# import os

points_np = filtered_points_np  # filtered_points_np должна быть определена заранее

if len(points_np) == 0:
    print("Облако точек пустое.")
else:
    scaler = StandardScaler()
    scaled_points_np = scaler.fit_transform(points_np)

    cutting_height = -1.2
    cut_indices = np.where(points_np[:, 2] > cutting_height)[0]
    cut_points_np = points_np[cut_indices]
    cut_scaled_points_np = scaled_points_np[cut_indices]

    n_neighbors = 1

    nbrs = NearestNeighbors(n_neighbors=n_neighbors, algorithm='auto').fit(cut_scaled_points_np)
    distances, indices = nbrs.kneighbors(cut_scaled_points_np)

    avg_distances = np.mean(distances, axis=1)

    threshold_low = np.percentile(avg_distances, 1)

    filtered_indices = np.where(avg_distances <= threshold_low)[0]
    filtered_points_np = cut_points_np[filtered_indices]

    center = np.mean(filtered_points_np, axis=0)

    center_point = o3d.geometry.TriangleMesh.create_sphere(radius=0.1)
    center_point.paint_uniform_color([1.0, 0.0, 0.0])
    center_point.translate(center)

    num_clusters = 15
    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(filtered_points_np)
    labels = kmeans.labels_

    max_label = labels.max()
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))

    kmeans_pcd = o3d.geometry.PointCloud()
    kmeans_pcd.points = o3d.utility.Vector3dVector(filtered_points_np)
    kmeans_pcd.colors = o3d.utility.Vector3dVector(colors[:, :3])

    bbox_list = []
    cluster_sizes = []
    for label in np.unique(labels):
        if label == -1:
            continue
        cluster_points = filtered_points_np[labels == label]
        bbox = o3d.geometry.AxisAlignedBoundingBox.create_from_points(o3d.utility.Vector3dVector(cluster_points))
        bbox.color = (0, 0, 0)
        bbox_list.append(bbox)
        cluster_sizes.append(len(cluster_points))

    lines = []
    for cluster_center in kmeans.cluster_centers_:
        line = o3d.geometry.LineSet()
        line.points = o3d.utility.Vector3dVector([center, cluster_center])
        line.lines = o3d.utility.Vector2iVector([[0, 1]])
        line.colors = o3d.utility.Vector3dVector([[0, 0, 0]])
        lines.append(line)

    o3d.visualization.draw_geometries([kmeans_pcd, center_point] + bbox_list + lines)
# Out:
# d:\Program\Anaconda\envs\tfenv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
import numpy as np
import os

for i, center_coord in enumerate(kmeans.cluster_centers_):
    distance_to_center = np.linalg.norm(center_coord)
    print(f"Cluster center {i}: {center_coord}, Distance to the center of coordinates: {distance_to_center}")

output_dir = r'D:\Cluster_proj\VIPCClustering\KITTI_clusters\experiment_000010\cluster'

os.makedirs(output_dir, exist_ok=True)

output_file_path = os.path.join(output_dir, "bbox_info.txt")

with open(output_file_path, "w", encoding="utf-8") as file:
    for i, bbox in enumerate(bbox_list, 1):
        file.write(f"bounding box {i}:\n")
        file.write(f"center: {bbox.get_center().tolist()}\n")
        file.write(f"Dimensions: {bbox.get_extent().tolist()}\n")
        file.write(f"Number of points in a cluster: {cluster_sizes[i-1]}\n")
        file.write(f"Distance to the center of coordinates: {np.linalg.norm(bbox.get_center())}\n")

        print(f"bounding box {i}:")
        print(f"center: {bbox.get_center()}")
        print(f"Dimensions: {bbox.get_extent()}")
        print(f"Number of points in a cluster: {cluster_sizes[i-1]}")
        print(f"Distance to the center of coordinates: {np.linalg.norm(bbox.get_center())}")

print(f"Save to: {output_file_path}")
# Out:
# Cluster center 0: [-3.8713398  -3.2828016  -0.88498604], Distance to the center of coordinates: 5.152403354644775
# Cluster center 1: [  2.188631   -15.751724    -0.23991439], Distance to the center of coordinates: 15.90485668182373
# Cluster center 2: [ 1.9504266  4.57518   -0.8449435], Distance to the center of coordinates: 5.044835567474365
# Cluster center 3: [-8.982605    7.3753433  -0.90766513], Distance to the center of coordinates: 11.657904624938965
# Cluster center 4: [15.530764   -5.5644464  -0.76592433], Distance to the center of coordinates: 16.515275955200195
# Cluster center 5: [ -4.172969  -11.924452   -0.2812395], Distance to the center of coordinates: 12.636665344238281
# Cluster center 6: [ -1.1393702 -13.85027    -0.2342656], Distance to the center of coordinates: 13.899030685424805
# Cluster center 7: [ 4.1119    -4.0379577 -0.8594338], Distance to the center of coordinates: 5.826786994934082
# Cluster center 8: [-23.648388   10.2114105   0.3779717], Distance to the center of coordinates: 25.761638641357422
# Cluster center 9: [11.260961    2.392365   -0.81736493], Distance to the center of coordinates: 11.541261672973633
# Cluster center 10: [-16.488213     3.0487309   -0.56922865], Distance to the center of coordinates: 16.77736473083496
# Cluster center 11: [-11.037345     3.3747344   -0.83865523], Distance to the center of coordinates: 11.572172164916992
# Cluster center 12: [ 6.6183777   7.231765   -0.17352256], Distance to the center of coordinates: 9.804665565490723
# Cluster center 13: [-12.396648   -5.0259185  -0.9687101], Distance to the center of coordinates: 13.411754608154297
# Cluster center 14: [  2.8330712 -11.058749   -0.7450309], Distance to the center of coordinates: 11.44016170501709
# bounding box 1:
# center: [-4.53550005 -3.61149991 -0.7175    ]
# Dimensions: [3.40299988 2.00699973 0.963     ]
# Number of points in a cluster: 2165
# Distance to the center of coordinates: 5.8419601607337786
# bounding box 2:
# center: [  2.54600006 -15.85900021  -0.2015    ]
# Dimensions: [4.05000007 4.00399971 1.995     ]
# Number of points in a cluster: 1406
# Distance to the center of coordinates: 16.063331102422733
# bounding box 3:
# center: [ 1.64599996  3.62149988 -0.6435    ]
# Dimensions: [3.02599992 6.32899979 1.111     ]
# Number of points in a cluster: 2941
# Distance to the center of coordinates: 4.029723254736465
# bounding box 4:
# center: [-9.42749977  7.47700024 -0.86500001]
# Dimensions: [1.61499977 1.3920002  0.66400003]
# Number of points in a cluster: 218
# Distance to the center of coordinates: 12.063644121397175
# bounding box 5:
# center: [16.5619998  -5.63849998 -0.71449998]
# Dimensions: [2.80000019 1.44700003 0.96699995]
# Number of points in a cluster: 251
# Distance to the center of coordinates: 17.510083651859777
# bounding box 6:
# center: [ -4.35450006 -12.64999962  -0.2385    ]
# Dimensions: [3.4749999  4.01399994 1.921     ]
# Number of points in a cluster: 2178
# Distance to the center of coordinates: 13.380621933605441
# bounding box 7:
# center: [ -1.05599999 -13.69000006  -0.24449998]
# Dimensions: [3.19799995 2.29799938 1.90699995]
# Number of points in a cluster: 1764
# Distance to the center of coordinates: 13.732844490327466
# bounding box 8:
# center: [ 4.51300013 -4.17350006 -0.76800001]
# Dimensions: [1.56000018 1.5710001  0.86199999]
# Number of points in a cluster: 1042
# Distance to the center of coordinates: 6.194763671762773
# bounding box 9:
# center: [-23.65350056  10.19449997   0.30850001]
# Dimensions: [0.35899925 1.65699959 1.55700001]
# Number of points in a cluster: 214
# Distance to the center of coordinates: 25.7587090219872
# bounding box 10:
# center: [12.05050039  3.55749995 -0.70350002]
# Dimensions: [3.73099995 4.45299995 0.98300005]
# Number of points in a cluster: 548
# Distance to the center of coordinates: 12.584326675058737
# bounding box 11:
# center: [-16.38850021   3.57199991  -0.55600002]
# Dimensions: [1.88100052 2.62199998 1.26200004]
# Number of points in a cluster: 293
# Distance to the center of coordinates: 16.78246878768285
# bounding box 12:
# center: [-11.47699976   3.33450013  -0.73800001]
# Dimensions: [2.42800045 3.1930002  0.92199999]
# Number of points in a cluster: 670
# Distance to the center of coordinates: 11.974350029761121
# bounding box 13:
# center: [ 6.71950006  7.27200007 -0.31249997]
# Dimensions: [1.11299992 0.5999999  1.73499995]
# Number of points in a cluster: 310
# Distance to the center of coordinates: 9.906125500657126
# bounding box 14:
# center: [-12.64650011  -5.03600001  -0.93850002]
# Dimensions: [1.66499996 1.38200045 0.51700002]
# Number of points in a cluster: 245
# Distance to the center of coordinates: 13.644634237102805
# bounding box 15:
# center: [  2.56349993 -11.28599977  -0.50499998]
# Dimensions: [1.77699995 1.03600025 1.38599995]
# Number of points in a cluster: 323
# Distance to the center of coordinates: 11.584487376587592
# Save to: D:\Cluster_proj\VIPCClustering\KITTI_clusters\experiment_000010\cluster\bbox_info.txt

# %% [markdown]
# # PART 3

# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from scipy.spatial.distance import pdist

def dunn_index(X, labels):
    # Check if the number of data points matches the number of labels
    if len(X) != len(labels):
        raise ValueError("Number of data points and labels do not match.")

    # Check if there are enough unique labels to form clusters
    unique_labels = np.unique(labels)
    if len(unique_labels) < 2:
        raise ValueError("At least two different clusters are required.")

    # Compute intra-cluster distances
    intra_cluster_distances = []
    for label in unique_labels:
        cluster_points = X[labels == label]
        if len(cluster_points) <= 1:
            intra_cluster_distances.append(0)  # Not enough data to assess intra-cluster distances
        else:
            intra_cluster_distances.append(np.max(pdist(cluster_points)))

    # Compute inter-cluster distances
    min_inter_cluster_distance = np.inf
    for i in range(len(unique_labels)):
        for j in range(i + 1, len(unique_labels)):
            cluster_points_i = X[labels == unique_labels[i]]
            cluster_points_j = X[labels == unique_labels[j]]
            inter_cluster_distance = np.min(pdist(np.vstack([cluster_points_i, cluster_points_j])))
            if inter_cluster_distance < min_inter_cluster_distance:
                min_inter_cluster_distance = inter_cluster_distance

    # Compute Dunn Index
    dunn_index_value = min_inter_cluster_distance / np.max(intra_cluster_distances)
    return dunn_index_value

points_np = filtered_points_np

if len(points_np) == 0:
    print("Облако точек пустое.")
else:
    scaler = StandardScaler()
    scaled_points_np = scaler.fit_transform(points_np)

    cutting_height = -1.2
    cut_indices = np.where(points_np[:, 2] > cutting_height)[0]
    cut_points_np = points_np[cut_indices]
    cut_scaled_points_np = scaled_points_np[cut_indices]

    n_neighbors = 1

    nbrs = NearestNeighbors(n_neighbors=n_neighbors, algorithm='auto').fit(cut_scaled_points_np)
    distances, indices = nbrs.kneighbors(cut_scaled_points_np)

    avg_distances = np.mean(distances, axis=1)

    threshold_low = np.percentile(avg_distances, 1)

    filtered_indices = np.where(avg_distances <= threshold_low)[0]
    filtered_points_np = cut_points_np[filtered_indices]

    center = np.mean(filtered_points_np, axis=0)

    center_point = o3d.geometry.TriangleMesh.create_sphere(radius=0.1)
    center_point.paint_uniform_color([1.0, 0.0, 0.0])
    center_point.translate(center)

    num_clusters = 15
    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(filtered_points_np)
    labels = kmeans.labels_

    silhouette_score_value = silhouette_score(filtered_points_np, labels)
    print("Silhouette Score:", silhouette_score_value)

    try:
        dunn_index_value = dunn_index(filtered_points_np, labels)
        print("Dunn Index:", dunn_index_value)
    except ValueError as e:
        print("Error:", e)

    davies_bouldin_value = davies_bouldin_score(filtered_points_np, labels)
    print("Davies-Bouldin Index:", davies_bouldin_value)

    calinski_harabasz_value = calinski_harabasz_score(filtered_points_np, labels)
    print("Calinski–Harabasz Index:", calinski_harabasz_value)
    calinski_harabasz_value = calinski_harabasz_score(filtered_points_np, labels)
    print("Calinski–Harabasz Index:", calinski_harabasz_value)

    c_index = calinski_harabasz_value / davies_bouldin_value
    print("C-index:", c_index)


    max_label = labels.max()
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))

    kmeans_pcd = o3d.geometry.PointCloud()
    kmeans_pcd.points = o3d.utility.Vector3dVector(filtered_points_np)
    kmeans_pcd.colors = o3d.utility.Vector3dVector(colors[:, :3])

    bbox_list = []
    for label in np.unique(labels):
        if label == -1:
            continue
        cluster_points = filtered_points_np[labels == label]
        bbox = o3d.geometry.AxisAlignedBoundingBox.create_from_points(o3d.utility.Vector3dVector(cluster_points))
        bbox.color = (0, 0, 0)
        bbox_list.append(bbox)

    lines = []
    for cluster_center in kmeans.cluster_centers_:
        line = o3d.geometry.LineSet()
        line.points = o3d.utility.Vector3dVector([center, cluster_center])
        line.lines = o3d.utility.Vector2iVector([[0, 1]])
        line.colors = o3d.utility.Vector3dVector([[0, 0, 0]])
        lines.append(line)

    o3d.visualization.draw_geometries([kmeans_pcd, center_point] + bbox_list + lines)
# Out:
# d:\Program\Anaconda\envs\tfenv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Silhouette Score: 0.71279114
# Dunn Index: 0.0009633907613852348
# Davies-Bouldin Index: 0.30853531137098905
# Calinski–Harabasz Index: 98050.39619632333
# Calinski–Harabasz Index: 98050.39619632333
# C-index: 317793.1101650325

# %%
def variety_index(X, labels):
    clusters = np.unique(labels)
    diversity_per_cluster = []
    for cluster in clusters:
        cluster_points = X[labels == cluster]
        if len(cluster_points) <= 1:
            diversity_per_cluster.append(0)
        else:
            distances = np.linalg.norm(cluster_points[:, None] - cluster_points, axis=-1)
            diversity_per_cluster.append(np.std(distances))
    return np.mean(diversity_per_cluster)

variety_index_value = variety_index(filtered_points_np, labels)
print("Variety Index:", variety_index_value)
# Out:
# Variety Index: 0.57030874

# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from scipy.spatial.distance import pdist

def dunn_index(X, labels):
    # Check if the number of data points matches the number of labels
    if len(X) != len(labels):
        raise ValueError("Number of data points and labels do not match.")

    # Check if there are enough unique labels to form clusters
    unique_labels = np.unique(labels)
    if len(unique_labels) < 2:
        raise ValueError("At least two different clusters are required.")

    # Compute intra-cluster distances
    intra_cluster_distances = []
    for label in unique_labels:
        cluster_points = X[labels == label]
        if len(cluster_points) <= 1:
            intra_cluster_distances.append(0)  # Not enough data to assess intra-cluster distances
        else:
            intra_cluster_distances.append(np.max(pdist(cluster_points)))

    min_inter_cluster_distance = np.inf
    for i in range(len(unique_labels)):
        for j in range(i + 1, len(unique_labels)):
            cluster_points_i = X[labels == unique_labels[i]]
            cluster_points_j = X[labels == unique_labels[j]]
            inter_cluster_distance = np.min(pdist(np.vstack([cluster_points_i, cluster_points_j])))
            if inter_cluster_distance < min_inter_cluster_distance:
                min_inter_cluster_distance = inter_cluster_distance

    dunn_index_value = min_inter_cluster_distance / np.max(intra_cluster_distances)
    return dunn_index_value

points_np = filtered_points_np

if len(points_np) == 0:
    print("Облако точек пустое.")
else:
    scaler = StandardScaler()
    scaled_points_np = scaler.fit_transform(points_np)

    cutting_height = -1.2
    cut_indices = np.where(points_np[:, 2] > cutting_height)[0]
    cut_points_np = points_np[cut_indices]
    cut_scaled_points_np = scaled_points_np[cut_indices]

    n_neighbors = 1

    nbrs = NearestNeighbors(n_neighbors=n_neighbors, algorithm='auto').fit(cut_scaled_points_np)
    distances, indices = nbrs.kneighbors(cut_scaled_points_np)

    avg_distances = np.mean(distances, axis=1)

    threshold_low = np.percentile(avg_distances, 1)

    filtered_indices = np.where(avg_distances <= threshold_low)[0]
    filtered_points_np = cut_points_np[filtered_indices]

    center = np.mean(filtered_points_np, axis=0)

    center_point = o3d.geometry.TriangleMesh.create_sphere(radius=0.1)
    center_point.paint_uniform_color([1.0, 0.0, 0.0])
    center_point.translate(center)

    num_clusters = 15
    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(filtered_points_np)
    labels = kmeans.labels_

    silhouette_score_value = silhouette_score(filtered_points_np, labels)
    print("Silhouette Score:", silhouette_score_value)

    try:
        dunn_index_value = dunn_index(filtered_points_np, labels)
        print("Dunn Index:", dunn_index_value)
    except ValueError as e:
        print("Error:", e)

    davies_bouldin_value = davies_bouldin_score(filtered_points_np, labels)
    print("Davies-Bouldin Index:", davies_bouldin_value)

    calinski_harabasz_value = calinski_harabasz_score(filtered_points_np, labels)
    print("Calinski–Harabasz Index:", calinski_harabasz_value)
    calinski_harabasz_value = calinski_harabasz_score(filtered_points_np, labels)
    print("Calinski–Harabasz Index:", calinski_harabasz_value)

    c_index = calinski_harabasz_value / davies_bouldin_value
    print("C-index:", c_index)


    max_label = labels.max()
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))

    kmeans_pcd = o3d.geometry.PointCloud()
    kmeans_pcd.points = o3d.utility.Vector3dVector(filtered_points_np)
    kmeans_pcd.colors = o3d.utility.Vector3dVector(colors[:, :3])

    bbox_list = []
    for label in np.unique(labels):
        if label == -1:
            continue
        cluster_points = filtered_points_np[labels == label]
        bbox = o3d.geometry.AxisAlignedBoundingBox.create_from_points(o3d.utility.Vector3dVector(cluster_points))
        bbox.color = (0, 0, 0)
        bbox_list.append(bbox)

    lines = []
    for cluster_center in kmeans.cluster_centers_:
        line = o3d.geometry.LineSet()
        line.points = o3d.utility.Vector3dVector([center, cluster_center])
        line.lines = o3d.utility.Vector2iVector([[0, 1]])
        line.colors = o3d.utility.Vector3dVector([[0, 0, 0]])
        lines.append(line)

    o3d.visualization.draw_geometries([kmeans_pcd, center_point] + bbox_list + lines)

    # Calculate distance from origin to each cluster center
    origin = np.array([0, 0, 0])
    cluster_centers = kmeans.cluster_centers_
    distances_to_origin = np.linalg.norm(cluster_centers - origin, axis=1)

    # Calculate the number of points in each cluster
    points_per_cluster = np.bincount(labels)

    # Print the results
    for i, (distance, num_points) in enumerate(zip(distances_to_origin, points_per_cluster)):
        print(f"Cluster {i}: Distance to origin = {distance:.2f}, Number of points = {num_points}")
# Out:
# d:\Program\Anaconda\envs\tfenv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Silhouette Score: 0.71279114
# Dunn Index: 0.0009633907613852348
# Davies-Bouldin Index: 0.30853531137098905
# Calinski–Harabasz Index: 98050.39619632333
# Calinski–Harabasz Index: 98050.39619632333
# C-index: 317793.1101650325
# Cluster 0: Distance to origin = 5.15, Number of points = 2165
# Cluster 1: Distance to origin = 15.90, Number of points = 1406
# Cluster 2: Distance to origin = 5.04, Number of points = 2941
# Cluster 3: Distance to origin = 11.66, Number of points = 218
# Cluster 4: Distance to origin = 16.52, Number of points = 251
# Cluster 5: Distance to origin = 12.64, Number of points = 2178
# Cluster 6: Distance to origin = 13.90, Number of points = 1764
# Cluster 7: Distance to origin = 5.83, Number of points = 1042
# Cluster 8: Distance to origin = 25.76, Number of points = 214
# Cluster 9: Distance to origin = 11.54, Number of points = 548
# Cluster 10: Distance to origin = 16.78, Number of points = 293
# Cluster 11: Distance to origin = 11.57, Number of points = 670
# Cluster 12: Distance to origin = 9.80, Number of points = 310
# Cluster 13: Distance to origin = 13.41, Number of points = 245
# Cluster 14: Distance to origin = 11.44, Number of points = 323

# %%
import os

output_dir = r'D:\Cluster_proj\VIPCClustering\KITTI_clusters\experiment_000010\cluster'

os.makedirs(output_dir, exist_ok=True)

output_file_path = os.path.join(output_dir, "indexes.txt")

with open(output_file_path, "w", encoding="utf-8") as file:
    file.write(f"Silhouette Score: {silhouette_score_value}\n")
    file.write(f"Dunn Index: {dunn_index_value}\n")
    file.write(f"Davies-Bouldin Index: {davies_bouldin_value}\n")
    file.write(f"Calinski–Harabasz Index: {calinski_harabasz_value}\n")
    file.write(f"C-index: {c_index}\n")

print(f"Save to: {output_file_path}")
# Out:
# Save to: D:\Cluster_proj\VIPCClustering\KITTI_clusters\experiment_000010\cluster\indexes.txt

# %%
import open3d as o3d
import numpy as np

velodyne_file = 'D:/Cluster_proj/VIPCClustering/data/KITTI/velodyne/000010.bin'

velo_points = np.fromfile(velodyne_file, dtype=np.float32).reshape(-1, 4)
points_np = velo_points[:, :3]

pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points_np)

labels_file = 'D:/Cluster_proj/annotator/kitti/data_object/training/gt_segmentation/000010.txt'
with open(labels_file, 'r') as file:
    labels = file.readlines()

colors = []
for label in labels:
    if 'BG' in label:
        colors.append([1, 0, 0])
    elif 'Car' in label:
        colors.append([0, 0, 0])

pcd.colors = o3d.utility.Vector3dVector(colors)

o3d.visualization.draw_geometries([pcd])

# %%
import open3d as o3d
import numpy as np

velodyne_file = 'D:/Cluster_proj/VIPCClustering/data/KITTI/velodyne/000010.bin'

velo_points = np.fromfile(velodyne_file, dtype=np.float32).reshape(-1, 4)
points_np = velo_points[:, :3]

pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points_np)

labels_file = 'D:/Cluster_proj/annotator/kitti/data_object/training/gt_segmentation/000010.txt'
with open(labels_file, 'r') as file:
    labels = file.readlines()

car_indices = []
for i, label in enumerate(labels):
    if 'Car' in label:
        car_indices.append(i)

colors = [[1, 0, 1]] * len(points_np)
for idx in car_indices:
    colors[idx] = [0, 0, 0]

pcd.colors = o3d.utility.Vector3dVector(colors)

o3d.visualization.draw_geometries([pcd])
